# %% [markdown]
# # Hands-on  Session 1

# %% [markdown]
# Libraries
# * Spacy
# * NLTK
# * StanfordCore NLP

# %% [markdown]
# ---

# %% [markdown]
# 1. Why different libraries?
# 2. What are their functionalities?
# 3. Architectural differences?
# 4. To understand the use of these libraries.

# %% [markdown]
# ### Why different libraries?

# %% [markdown]
# ![Comparison-of-functionalities-offered-by-SpaCy-NLTK-and-CoreNLP-14.png](attachment:Comparison-of-functionalities-offered-by-SpaCy-NLTK-and-CoreNLP-14.png)

# %% [markdown]
# ### What are their functionalities?
#
# 1. Spacy
# 2. NLTK
# 3. CoreNLP

# %% [markdown]
# ### Architectural differences?

# %% [markdown]
# * NLTK

# %% [markdown]
# ![Screenshot%20from%202023-06-25%2017-23-34.png](attachment:Screenshot%20from%202023-06-25%2017-23-34.png)

# %% [markdown]
# * Spacy

# %% [markdown]
# ![Screenshot%20from%202023-06-25%2017-04-09.png](attachment:Screenshot%20from%202023-06-25%2017-04-09.png)

# %% [markdown]
# * CoreNLP

# %% [markdown]
# ![Screenshot%20from%202023-06-25%2017-16-48.png](attachment:Screenshot%20from%202023-06-25%2017-16-48.png)

# %% [markdown]
# ### Lets start then.

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Apple PROPN nsubj
# is AUX aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.K. PROPN dobj
# startup NOUN dobj
# for ADP prep
# $ SYM quantmod
# 1 NUM compound
# billion NUM pobj

# %%
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Apple Apple PROPN NNP nsubj Xxxxx True False
# is be AUX VBZ aux xx True True
# looking look VERB VBG ROOT xxxx True False
# at at ADP IN prep xx True True
# buying buy VERB VBG pcomp xxxx True False
# U.K. U.K. PROPN NNP dobj X.X. False False
# startup startup NOUN NN dobj xxxx True False
# for for ADP IN prep xxx True True
# $ $ SYM $ quantmod $ False False
# 1 1 NUM CD compound d False False
# billion billion NUM CD pobj xxxx True False

# %%
# Out:
# 322 32
